# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#!conda install -y -c conda-forge xgboost

# %%
from sklearn.base import BaseEstimator,MetaEstimatorMixin
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import train_test_split
import xgboost as xgb

# %%
#for some statistics
from scipy import stats
from scipy.stats import norm, skew 
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax

# %%
sns.set_style('whitegrid')
pd.options.display.max_rows = 100

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore')

# %% [markdown]
# # Data

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train_Id = train['Id']
test_Id = test['Id']

# %% [markdown]
# # EDA

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(12,6))
train['SalePrice'].hist(bins=50)
print('skewness: {:.3f}'.format(train['SalePrice'].skew()))
print('kurotsis: {:.3f}'.format(train['SalePrice'].kurt()))
# Out:
# skewness: 1.883
# kurotsis: 6.536

# %%
# target value dist,comapred with normal dist of target

# transforming target value to log(x), ML algs do well with normally distributed data

fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(16,7))


sns.distplot(train['SalePrice'],fit=norm,ax=ax[0])
ax[0].set_title('Original distribution')


sns.distplot(np.log1p(train['SalePrice']),fit=norm,ax=ax[1])
ax[1].set_title('log1p Transformation')

plt.show()

# %% [markdown]
# # Data summary

# %%
df_summ = train.drop(['Id','SalePrice'],axis=1)

summary = pd.DataFrame({'dtype':df_summ.dtypes,'unique':df_summ.nunique(),
              'values':{ str(i):df_summ[i].value_counts().index.tolist() for i in df_summ.columns.tolist()},
             'null':df_summ.isnull().sum()}).sort_values(by='null',ascending=False)

# %%
## Understaing the data
summary.head()
# Out:
#               dtype  unique                      values  null
# PoolQC       object       3                [Gd, Fa, Ex]  1453
# MiscFeature  object       4    [Shed, Gar2, Othr, TenC]  1406
# Alley        object       2                [Grvl, Pave]  1369
# Fence        object       4  [MnPrv, GdPrv, GdWo, MnWw]  1179
# FireplaceQu  object       5        [Gd, TA, Fa, Ex, Po]   690

# %%
catagorical_features = summary.loc[summary['dtype'] == 'object','dtype'].index.tolist()
numarical_features = summary.loc[summary['dtype'] != 'object','dtype'].index.tolist()

# %%
df = train.drop('Id',axis=1)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
# 2       0      9    2008        WD         Normal     223500
# 3       0      2    2006        WD        Abnorml     140000
# 4       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %% [markdown]
# # Univariate Analysis

# %%
# lets start with YearBuilt,YearRemodAdd,YrSold
df[['YearBuilt','YearRemodAdd','YrSold']].head()

#print('\n')

#df[['YearBuilt','YearRemodAdd','YrSold']].isnull().any()
# Out:
#    YearBuilt  YearRemodAdd  YrSold
# 0       2003          2003    2008
# 1       1976          1976    2007
# 2       2001          2002    2008
# 3       1915          1970    2006
# 4       2000          2000    2008

# %%
year_bar = df[['YrSold','SalePrice']].groupby('YrSold').mean()

plt.bar(year_bar.index.tolist(),height=year_bar['SalePrice']);

# %%
df[['YrSold','SalePrice']].corr()
# Out:
#              YrSold  SalePrice
# YrSold     1.000000  -0.028923
# SalePrice -0.028923   1.000000

# %%
df[['YearBuilt','YearRemodAdd','YrSold','SalePrice']].corr()['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice       1.000000
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# YrSold         -0.028923
# Name: SalePrice, dtype: float64

# %%
df['age'] = df['YrSold'] - df['YearBuilt'] 

df['age_re'] = df['YrSold'] - df['YearRemodAdd']

# %%
df[['age','age_re','SalePrice']].corr()['SalePrice']
# Out:
# age         -0.523350
# age_re      -0.509079
# SalePrice    1.000000
# Name: SalePrice, dtype: float64

# %%
df['age_total'] = df['age'] - (df['age_re'] * 0.1)

# %%
plt.scatter(df['age_total'],df['SalePrice'],alpha=0.5);

# %%
df[['age_total','SalePrice']].corr()
# Out:
#            age_total  SalePrice
# age_total   1.000000  -0.508431
# SalePrice  -0.508431   1.000000

# %%
df['age'].hist(bins=70);

# %%
df[['MoSold','SalePrice']].corr()
# Out:
#              MoSold  SalePrice
# MoSold     1.000000   0.046432
# SalePrice  0.046432   1.000000

# %%
df['age_re'].hist(bins=50);

# %%
plt.scatter(df['age'],df['SalePrice'],alpha=0.5);

# %%
plt.scatter(df['age_re'],df['SalePrice'],alpha=0.5);

# %% [markdown]
# # Bivariate Analysis

# %%
df[numarical_features].isnull().sum() #LotFrontage GarageYrBlt MasVnrArea
# Out:
# LotFrontage      259
# GarageYrBlt       81
# MasVnrArea         8
# MiscVal            0
# MoSold             0
# 1stFlrSF           0
# OpenPorchSF        0
# MSSubClass         0
# LowQualFinSF       0
# OverallCond        0
# YearRemodAdd       0
# YearBuilt          0
# WoodDeckSF         0
# TotalBsmtSF        0
# TotRmsAbvGrd       0
# ScreenPorch        0
# OverallQual        0
# PoolArea           0
# LotArea            0
# HalfBath           0
# 3SsnPorch          0
# BedroomAbvGr       0
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtFullBath       0
# BsmtHalfBath       0
# BsmtUnfSF          0
# EnclosedPorch      0
# Fireplaces         0
# FullBath           0
# GarageArea         0
# GarageCars         0
# GrLivArea          0
# 2ndFlrSF           0
# KitchenAbvGr       0
# YrSold             0
# dtype: int64

# %%
df[['LotFrontage','GarageYrBlt','MasVnrArea','SalePrice']].corr()
# Out:
#              LotFrontage  GarageYrBlt  MasVnrArea  SalePrice
# LotFrontage     1.000000     0.070250    0.193458   0.351799
# GarageYrBlt     0.070250     1.000000    0.252691   0.486362
# MasVnrArea      0.193458     0.252691    1.000000   0.477493
# SalePrice       0.351799     0.486362    0.477493   1.000000

# %%
df[['LotFrontage','GarageYrBlt','MasVnrArea','SalePrice']].head()
# Out:
#    LotFrontage  GarageYrBlt  MasVnrArea  SalePrice
# 0         65.0       2003.0       196.0     208500
# 1         80.0       1976.0         0.0     181500
# 2         68.0       2001.0       162.0     223500
# 3         60.0       1998.0         0.0     140000
# 4         84.0       2000.0       350.0     250000

# %%
#['Id','GarageFinish','GarageQual','GarageType','GarageYrBlt','GarageCond']

df.loc[df['GarageYrBlt'].isnull(),['GarageFinish','GarageQual','GarageType','GarageYrBlt','GarageCond']].head()
# Out:
#    GarageFinish GarageQual GarageType  GarageYrBlt GarageCond
# 39          NaN        NaN        NaN          NaN        NaN
# 48          NaN        NaN        NaN          NaN        NaN
# 78          NaN        NaN        NaN          NaN        NaN
# 88          NaN        NaN        NaN          NaN        NaN
# 89          NaN        NaN        NaN          NaN        NaN

# %%
df.loc[df['GarageYrBlt'].isnull(),['GarageYrBlt','YearBuilt','YearRemodAdd','SalePrice']].head()
# Out:
#     GarageYrBlt  YearBuilt  YearRemodAdd  SalePrice
# 39          NaN       1955          1955      82000
# 48          NaN       1920          2008     113000
# 78          NaN       1968          1968     136500
# 88          NaN       1915          1982      85000
# 89          NaN       1994          1995     123600

# %%
df['FireplaceQu'].value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
df_cat = df[catagorical_features]
df_cat['FireplaceQu'].value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
df_cat['SalePrice'] = train['SalePrice']
df_cat.groupby('FireplaceQu')['SalePrice'].mean().sort_values().plot(kind='bar');

# %%
df_cat.groupby('FireplaceQu')['SalePrice'].sum().sort_values().plot(kind='bar');

# %%
df_cat.groupby('FireplaceQu')['SalePrice'].mean().sort_values()
# Out:
# FireplaceQu
# Po    129764.150000
# Fa    167298.484848
# TA    205723.488818
# Gd    226351.415789
# Ex    337712.500000
# Name: SalePrice, dtype: float64

# %%
df_cat.groupby('FireplaceQu')['SalePrice'].median().sort_values().plot(kind='bar');

# %% [markdown]
# # Observation on categorical features:
#
# * None values are not missing values, those are the facilities not available in the property
# * We can not fill null values to 0, because those features are ordinal, we undermine the ordinality of the features when we encode these features into numbers.
# * to find the ordinal relationship between classes in the features w.r.t Salespric, I used mean salse price within the classes in the feature and sort them in sequence and encoded them acc. to the sequence.
#
# # Observations on numerical features:
#
# * Fill  the missing values with 0
# * use mean for missing years
# * Month sold is not useful
# * Skewed features need to transformed with boxcox1p transformation

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# # Feature Engineering

# %%
## categorical features
## encoding all missing values to 'None' to a string, 
## to find the ordinal relationship between classes in the features w.r.t Salespric
## I used mean salse price within the classes in the feature and sort them in sequence and encoded them acc. to the sequence.

df_cat = df[catagorical_features]
df_cat['SalePrice'] = df['SalePrice']
df_cat.fillna('None',inplace=True)

cate_dict = {}

def catagorical_feat_dict(features,df_cat):
    
    for feat in features:

        df_features = df_cat[[feat,'SalePrice']].groupby(by = feat)['SalePrice'].mean().sort_values().index.tolist()
        
        #dict_feat = feat :{clas:df_features.index(clas) for clas in df_features}
        
        cate_dict.update({feat :{clas:df_features.index(clas) for clas in df_features}})
        
    return cate_dict

# %%
cata_dict = catagorical_feat_dict(catagorical_features,df_cat)

# %%
# Age,GarageAge

def year_transform(df):
    
    """ 
     Sorry this transformation dose nothing, I tryed diffrent methods but its not imporoving much, 
     I leftn it here for future updates on feature engineering. 
    """  
    df_num = df[numarical_features].fillna(value=0)

    df_num['Age'] = df_num['YearBuilt'] 
    
    df_num['AgeRemod'] = df_num['YearRemodAdd']

    df_num['GarageAge'] = df_num['GarageYrBlt']
    
    df_num.drop(['YrSold','YearBuilt','YearRemodAdd','GarageYrBlt'],axis=1,inplace=True)
    
    return df_num

# %%
df_num = year_transform(df)

# %%
#test_num = year_transform(train)

# %%
#df_num.loc[df_num['GarageAge'].isnull()]

# %%
#df_num.head().T

# %%
# gettng skewed features
skew_features = df_num.apply(lambda x: skew(x)).sort_values(ascending=False)

# %%
# using boxcox trasformation

def skew_transform(df_num):

    for fet in skew_features.index:
        
        if skew_features[fet] >0.70:
            try:
                df_num[fet] = boxcox1p(df_num[fet], boxcox_normmax(df_num[fet] + 1))
            except:
                print('error')

    return df_num

# %%
# skew transformajtions
df_num = skew_transform(df_num)

# %%
# skew trasformation
#test_num = skew_transform(test_num)

# %%
# change in skewness of the data
pd.DataFrame({'skew_before':skew_features,'skew_after':df_num.apply(lambda x: skew(x)).sort_values(ascending=False)}).sort_values(by='skew_before',ascending=False)
# Out:
#                skew_before  skew_after
# MiscVal          24.451640    5.199813
# PoolArea         14.813135   14.476284
# LotArea          12.195142   -0.185294
# 3SsnPorch        10.293752    7.744137
# LowQualFinSF      9.002080    7.392523
# KitchenAbvGr      4.483784    3.953381
# BsmtFinSF2        4.250888    2.645006
# ScreenPorch       4.117977    3.328194
# BsmtHalfBath      4.099186    3.925130
# EnclosedPorch     3.086696    2.285796
# MasVnrArea        2.674865    0.953281
# OpenPorchSF       2.361912    0.624656
# BsmtFinSF1        1.683771    0.381851
# WoodDeckSF        1.539792    0.776782
# TotalBsmtSF       1.522688    0.452285
# MSSubClass        1.406210    0.431145
# 1stFlrSF          1.375342   -0.006599
# GrLivArea         1.365156    0.005867
# BsmtUnfSF         0.919323    0.053031
# 2ndFlrSF          0.812194    0.883107
# OverallCond       0.692355    0.692355
# TotRmsAbvGrd      0.675646    0.675646
# HalfBath          0.675203    0.675203
# Fireplaces        0.648898    0.648898
# BsmtFullBath      0.595454    0.595454
# LotFrontage       0.267547    0.267547
# OverallQual       0.216721    0.216721
# MoSold            0.211835    0.211835
# BedroomAbvGr      0.211572    0.211572
# GarageArea        0.179796    0.179796
# FullBath          0.036524    0.036524
# GarageCars       -0.342197   -0.342197
# AgeRemod         -0.503044   -0.503044
# Age              -0.612831   -0.612831
# GarageAge        -3.865524   -3.865524

# %%
def cata_transform(df,catagorical_features):
    
    df_cata = df[catagorical_features].fillna('None')
    
    for feat in catagorical_features:
        
        # map feature to encod values as in cat_dict
        df_cata[feat] = df_cata[feat].map(cata_dict[feat])
        
    return df_cata

# %%
df_cat.head()
# Out:
#   PoolQC MiscFeature Alley Fence FireplaceQu GarageCond GarageFinish  \
# 0   None        None  None  None        None         TA          RFn
# 1   None        None  None  None          TA         TA          RFn
# 2   None        None  None  None          TA         TA          RFn
# 3   None        None  None  None          Gd         TA          Unf
# 4   None        None  None  None          TA         TA          RFn
#
#   GarageQual GarageType BsmtExposure  ... ExterQual Exterior1st Exterior2nd  \
# 0         TA     Attchd           No  ...        Gd     VinylSd     VinylSd
# 1         TA     Attchd           Gd  ...        TA     MetalSd     MetalSd
# 2         TA     Attchd           Mn  ...        Gd     VinylSd     VinylSd
# 3         TA     Detchd           No  ...        TA     Wd Sdng     Wd Shng
# 4         TA     Attchd           Av  ...        Gd     VinylSd     VinylSd
#
#   Foundation Functional Heating HeatingQC HouseStyle KitchenQual SalePrice
# 0      PConc        Typ    GasA        Ex     2Story          Gd    208500
# 1     CBlock        Typ    GasA        Ex     1Story          TA    181500
# 2      PConc        Typ    GasA        Ex     2Story          Gd    223500
# 3     BrkTil        Typ    GasA        Gd     2Story          Gd    140000
# 4      PConc        Typ    GasA        Ex     2Story          Gd    250000
#
# [5 rows x 44 columns]

# %%
# catagorical data trasformatin (label encoding)
df_cat = cata_transform(df_cat,catagorical_features)

# %%
#test_cat = cata_transform(test,catagorical_features)

# %%
# merging numarical features and catagorical features
df_x = pd.concat([df_num,df_cat],axis=1)

# %%
## Adding new features

def add_new_features(df):
    
    df['TotalSF']=df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']

    df['Total_sqr_footage'] = (df['BsmtFinSF1'] + df['BsmtFinSF2'] +
                                 df['1stFlrSF'] + df['2ndFlrSF'])

    df['Total_Bathrooms'] = (df['FullBath'] + (0.5 * df['HalfBath']) +
                               df['BsmtFullBath'] + (0.5 * df['BsmtHalfBath']))

    df['Total_porch_sf'] = (df['OpenPorchSF'] + df['3SsnPorch'] +
                              df['EnclosedPorch'] + df['ScreenPorch'] +
                              df['WoodDeckSF'])
    
    return df

# %%
# adding new additional features
df_x = add_new_features(df_x)

# %%
# transforming target value to log as requried on kaggle
y = np.log1p(train['SalePrice'])

df_new = df_x[['TotalSF','Total_sqr_footage','Total_Bathrooms','Total_porch_sf']]
df_new['SalePrice'] = y

# %%
## correlation between new features and Saleprice 
df_new[['TotalSF','Total_sqr_footage','Total_Bathrooms','Total_porch_sf','SalePrice']].corr()
# Out:
#                     TotalSF  Total_sqr_footage  Total_Bathrooms  \
# TotalSF            1.000000           0.990465         0.448451
# Total_sqr_footage  0.990465           1.000000         0.429910
# Total_Bathrooms    0.448451           0.429910         1.000000
# Total_porch_sf     0.216200           0.188791         0.364836
# SalePrice          0.424689           0.363444         0.672885
#
#                    Total_porch_sf  SalePrice
# TotalSF                  0.216200   0.424689
# Total_sqr_footage        0.188791   0.363444
# Total_Bathrooms          0.364836   0.672885
# Total_porch_sf           1.000000   0.440537
# SalePrice                0.440537   1.000000

# %%
# transforming target value to log as requried on kaggle
#y = np.log1p(train['SalePrice'])

# %%
# train ans validation sets
X_train, X_val, y_train, y_val = train_test_split(df_x, y, test_size=0.20, random_state=42)

# %% [markdown]
# # Models

# %%
xgb_reg = xgb.XGBRegressor(max_depth=10,eta=0.1,subsample=0.7,n_estimators=250)

# %%
X_train.shape
# Out:
# (1168, 82)

# %% [markdown]
# # Training

# %%
xgb_reg.fit(X_train,y_train, eval_set = [(X_train, y_train), (X_val, y_val)])
# Out:
# [12:51:32] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10.3869	validation_1-rmse:10.3556
# [1]	validation_0-rmse:9.35149	validation_1-rmse:9.32034
# [2]	validation_0-rmse:8.42109	validation_1-rmse:8.39015
# [3]	validation_0-rmse:7.58222	validation_1-rmse:7.55153
# [4]	validation_0-rmse:6.82648	validation_1-rmse:6.79604
# [5]	validation_0-rmse:6.14667	validation_1-rmse:6.11715
# [6]	validation_0-rmse:5.53458	validation_1-rmse:5.5059
# [7]	validation_0-rmse:4.98385	validation_1-rmse:4.9553
# [8]	validation_0-rmse:4.48857	validation_1-rmse:4.46171
# [9]	validation_0-rmse:4.04253	validation_1-rmse:4.0184
# [10]	validation_0-rmse:3.64127	validation_1-rmse:3.61731
# [11]	validation_0-rmse:3.27922	validation_1-rmse:3.25568
# [12]	validation_0-rmse:2.9533	validation_1-rmse:2.93179
# [13]	validation_0-rmse:2.66144	validation_1-rmse:2.63914
# [14]	validation_0-rmse:2.39901	validation_1-rmse:2.37773
# [15]	validation_0-rmse:2.16163	validation_1-rmse:2.14186
# [16]	validation_0-rmse:1.94801	validation_1-rmse:1.92982
# [17]	validation_0-rmse:1.7556	validation_1-rmse:1.73919
# [18]	validation_0-rmse:1.58304	validation_1-rmse:1.56755
# [19]	validation_0-rmse:1.42783	validation_1-rmse:1.41442
# [20]	validation_0-rmse:1.28822	validation_1-rmse:1.27608
# [21]	validation_0-rmse:1.16227	validation_1-rmse:1.15263
# [22]	validation_0-rmse:1.04899	validation_1-rmse:1.04002
# [23]	validation_0-rmse:0.947592	validation_1-rmse:0.94111
# [24]	validation_0-rmse:0.856123	validation_1-rmse:0.851378
# [25]	validation_0-rmse:0.773315	validation_1-rmse:0.771244
# [26]	validation_0-rmse:0.699511	validation_1-rmse:0.699541
# [27]	validation_0-rmse:0.633051	validation_1-rmse:0.633669
# [28]	validation_0-rmse:0.572774	validation_1-rmse:0.574972
# [29]	validation_0-rmse:0.518709	validation_1-rmse:0.522654
# [30]	validation_0-rmse:0.470165	validation_1-rmse:0.475201
# [31]	validation_0-rmse:0.42629	validation_1-rmse:0.433509
# [32]	validation_0-rmse:0.387451	validation_1-rmse:0.396004
# [33]	validation_0-rmse:0.351956	validation_1-rmse:0.362448
# [34]	validation_0-rmse:0.319674	validation_1-rmse:0.33222
# [35]	validation_0-rmse:0.291767	validation_1-rmse:0.306074
# [36]	validation_0-rmse:0.266049	validation_1-rmse:0.282744
# [37]	validation_0-rmse:0.243447	validation_1-rmse:0.263137
# [38]	validation_0-rmse:0.222428	validation_1-rmse:0.246223
# [39]	validation_0-rmse:0.203693	validation_1-rmse:0.230455
# [40]	validation_0-rmse:0.186899	validation_1-rmse:0.216667
# [41]	validation_0-rmse:0.171677	validation_1-rmse:0.205632
# [42]	validation_0-rmse:0.157986	validation_1-rmse:0.195356
# [43]	validation_0-rmse:0.145889	validation_1-rmse:0.186727
# [44]	validation_0-rmse:0.134935	validation_1-rmse:0.17937
# [45]	validation_0-rmse:0.125031	validation_1-rmse:0.173697
# [46]	validation_0-rmse:0.116202	validation_1-rmse:0.168759
# [47]	validation_0-rmse:0.108077	validation_1-rmse:0.164416
# [48]	validation_0-rmse:0.101093	validation_1-rmse:0.160541
# [49]	validation_0-rmse:0.094449	validation_1-rmse:0.157233
# [50]	validation_0-rmse:0.088581	validation_1-rmse:0.154722
# [51]	validation_0-rmse:0.083268	validation_1-rmse:0.152172
# [52]	validation_0-rmse:0.078333	validation_1-rmse:0.150538
# [53]	validation_0-rmse:0.074306	validation_1-rmse:0.14916
# [54]	validation_0-rmse:0.070018	validation_1-rmse:0.147572
# [55]	validation_0-rmse:0.066347	validation_1-rmse:0.146393
# [56]	validation_0-rmse:0.063013	validation_1-rmse:0.145347
# [57]	validation_0-rmse:0.060156	validation_1-rmse:0.144069
# [58]	validation_0-rmse:0.057243	validation_1-rmse:0.143698
# [59]	validation_0-rmse:0.054558	validation_1-rmse:0.14324
# [60]	validation_0-rmse:0.052059	validation_1-rmse:0.143026
# [61]	validation_0-rmse:0.050166	validation_1-rmse:0.142205
# [62]	validation_0-rmse:0.04838	validation_1-rmse:0.141861
# [63]	validation_0-rmse:0.046053	validation_1-rmse:0.14183
# [64]	validation_0-rmse:0.044339	validation_1-rmse:0.141667
# [65]	validation_0-rmse:0.043087	validation_1-rmse:0.141467
# [66]	validation_0-rmse:0.041572	validation_1-rmse:0.140886
# [67]	validation_0-rmse:0.040329	validation_1-rmse:0.140479
# [68]	validation_0-rmse:0.039387	validation_1-rmse:0.140334
# [69]	validation_0-rmse:0.037953	validation_1-rmse:0.13999
# [70]	validation_0-rmse:0.036909	validation_1-rmse:0.13999
# [71]	validation_0-rmse:0.0359	validation_1-rmse:0.140033
# [72]	validation_0-rmse:0.035097	validation_1-rmse:0.139846
# [73]	validation_0-rmse:0.034336	validation_1-rmse:0.139704
# [74]	validation_0-rmse:0.033481	validation_1-rmse:0.139444
# [75]	validation_0-rmse:0.032875	validation_1-rmse:0.139462
# [76]	validation_0-rmse:0.03182	validation_1-rmse:0.139426
# [77]	validation_0-rmse:0.030882	validation_1-rmse:0.1393
# [78]	validation_0-rmse:0.030324	validation_1-rmse:0.139278
# [79]	validation_0-rmse:0.029453	validation_1-rmse:0.139136
# [80]	validation_0-rmse:0.028571	validation_1-rmse:0.139335
# [81]	validation_0-rmse:0.027675	validation_1-rmse:0.139304
# [82]	validation_0-rmse:0.026883	validation_1-rmse:0.139347
# [83]	validation_0-rmse:0.026223	validation_1-rmse:0.1393
# [84]	validation_0-rmse:0.025484	validation_1-rmse:0.1394
# [85]	validation_0-rmse:0.024616	validation_1-rmse:0.1394
# [86]	validation_0-rmse:0.024249	validation_1-rmse:0.139427
# [87]	validation_0-rmse:0.023464	validation_1-rmse:0.139365
# [88]	validation_0-rmse:0.022587	validation_1-rmse:0.139372
# [89]	validation_0-rmse:0.022038	validation_1-rmse:0.139306
# [90]	validation_0-rmse:0.021536	validation_1-rmse:0.13934
# [91]	validation_0-rmse:0.020908	validation_1-rmse:0.1393
# [92]	validation_0-rmse:0.020435	validation_1-rmse:0.139175
# [93]	validation_0-rmse:0.020001	validation_1-rmse:0.13919
# [94]	validation_0-rmse:0.019604	validation_1-rmse:0.139182
# [95]	validation_0-rmse:0.019014	validation_1-rmse:0.139132
# [96]	validation_0-rmse:0.018669	validation_1-rmse:0.139253
# [97]	validation_0-rmse:0.018187	validation_1-rmse:0.139144
# [98]	validation_0-rmse:0.017712	validation_1-rmse:0.13899
# [99]	validation_0-rmse:0.017171	validation_1-rmse:0.138946
# [100]	validation_0-rmse:0.016743	validation_1-rmse:0.138888
# [101]	validation_0-rmse:0.016252	validation_1-rmse:0.138819
# [102]	validation_0-rmse:0.016066	validation_1-rmse:0.138811
# [103]	validation_0-rmse:0.015636	validation_1-rmse:0.138749
# [104]	validation_0-rmse:0.015146	validation_1-rmse:0.138794
# [105]	validation_0-rmse:0.014693	validation_1-rmse:0.138743
# [106]	validation_0-rmse:0.014258	validation_1-rmse:0.138626
# [107]	validation_0-rmse:0.014013	validation_1-rmse:0.138597
# [108]	validation_0-rmse:0.013762	validation_1-rmse:0.138655
# [109]	validation_0-rmse:0.013472	validation_1-rmse:0.138601
# [110]	validation_0-rmse:0.01313	validation_1-rmse:0.138583
# [111]	validation_0-rmse:0.012785	validation_1-rmse:0.138563
# [112]	validation_0-rmse:0.012401	validation_1-rmse:0.13855
# [113]	validation_0-rmse:0.012235	validation_1-rmse:0.138555
# [114]	validation_0-rmse:0.011886	validation_1-rmse:0.138589
# [115]	validation_0-rmse:0.011622	validation_1-rmse:0.13853
# [116]	validation_0-rmse:0.011198	validation_1-rmse:0.138601
# [117]	validation_0-rmse:0.010879	validation_1-rmse:0.138694
# [118]	validation_0-rmse:0.010734	validation_1-rmse:0.138674
# [119]	validation_0-rmse:0.010472	validation_1-rmse:0.138685
# [120]	validation_0-rmse:0.010254	validation_1-rmse:0.138634
# [121]	validation_0-rmse:0.010041	validation_1-rmse:0.138642
# [122]	validation_0-rmse:0.009723	validation_1-rmse:0.138614
# [123]	validation_0-rmse:0.009512	validation_1-rmse:0.138585
# [124]	validation_0-rmse:0.009236	validation_1-rmse:0.138609
# [125]	validation_0-rmse:0.009029	validation_1-rmse:0.138616
# [126]	validation_0-rmse:0.008765	validation_1-rmse:0.13856
# [127]	validation_0-rmse:0.00864	validation_1-rmse:0.138536
# [128]	validation_0-rmse:0.008391	validation_1-rmse:0.13852
# [129]	validation_0-rmse:0.008205	validation_1-rmse:0.138461
# [130]	validation_0-rmse:0.007983	validation_1-rmse:0.138479
# [131]	validation_0-rmse:0.00779	validation_1-rmse:0.138461
# [132]	validation_0-rmse:0.007566	validation_1-rmse:0.138456
# [133]	validation_0-rmse:0.00734	validation_1-rmse:0.138516
# [134]	validation_0-rmse:0.007072	validation_1-rmse:0.138449
# [135]	validation_0-rmse:0.006901	validation_1-rmse:0.138458
# [136]	validation_0-rmse:0.006687	validation_1-rmse:0.138436
# [137]	validation_0-rmse:0.006524	validation_1-rmse:0.138454
# [138]	validation_0-rmse:0.006312	validation_1-rmse:0.138389
# [139]	validation_0-rmse:0.006178	validation_1-rmse:0.138378
# [140]	validation_0-rmse:0.006034	validation_1-rmse:0.138381
# [141]	validation_0-rmse:0.005863	validation_1-rmse:0.138412
# [142]	validation_0-rmse:0.005741	validation_1-rmse:0.138413
# [143]	validation_0-rmse:0.00557	validation_1-rmse:0.138436
# [144]	validation_0-rmse:0.00543	validation_1-rmse:0.138473
# [145]	validation_0-rmse:0.00532	validation_1-rmse:0.138445
# [146]	validation_0-rmse:0.005196	validation_1-rmse:0.138455
# [147]	validation_0-rmse:0.0051	validation_1-rmse:0.138448
# [148]	validation_0-rmse:0.004969	validation_1-rmse:0.138438
# [149]	validation_0-rmse:0.004892	validation_1-rmse:0.138455
# [150]	validation_0-rmse:0.004836	validation_1-rmse:0.138439
# [151]	validation_0-rmse:0.004677	validation_1-rmse:0.138433
# [152]	validation_0-rmse:0.0046	validation_1-rmse:0.138415
# [153]	validation_0-rmse:0.004478	validation_1-rmse:0.138411
# [154]	validation_0-rmse:0.004428	validation_1-rmse:0.138406
# [155]	validation_0-rmse:0.004266	validation_1-rmse:0.138417
# [156]	validation_0-rmse:0.00421	validation_1-rmse:0.138396
# [157]	validation_0-rmse:0.004137	validation_1-rmse:0.138391
# [158]	validation_0-rmse:0.00402	validation_1-rmse:0.138415
# [159]	validation_0-rmse:0.003938	validation_1-rmse:0.138409
# [160]	validation_0-rmse:0.003863	validation_1-rmse:0.13842
# [161]	validation_0-rmse:0.003777	validation_1-rmse:0.138432
# [162]	validation_0-rmse:0.003684	validation_1-rmse:0.138448
# [163]	validation_0-rmse:0.00362	validation_1-rmse:0.138447
# [164]	validation_0-rmse:0.003534	validation_1-rmse:0.138443
# [165]	validation_0-rmse:0.003437	validation_1-rmse:0.138431
# [166]	validation_0-rmse:0.003334	validation_1-rmse:0.138417
# [167]	validation_0-rmse:0.003285	validation_1-rmse:0.138408
# [168]	validation_0-rmse:0.003198	validation_1-rmse:0.13841
# [169]	validation_0-rmse:0.003097	validation_1-rmse:0.138421
# [170]	validation_0-rmse:0.003023	validation_1-rmse:0.138409
# [171]	validation_0-rmse:0.002977	validation_1-rmse:0.138408
# [172]	validation_0-rmse:0.00291	validation_1-rmse:0.13839
# [173]	validation_0-rmse:0.002837	validation_1-rmse:0.138387
# [174]	validation_0-rmse:0.002786	validation_1-rmse:0.138383
# [175]	validation_0-rmse:0.002704	validation_1-rmse:0.138406
# [176]	validation_0-rmse:0.002635	validation_1-rmse:0.138427
# [177]	validation_0-rmse:0.002574	validation_1-rmse:0.138414
# [178]	validation_0-rmse:0.002513	validation_1-rmse:0.138413
# [179]	validation_0-rmse:0.002465	validation_1-rmse:0.13842
# [180]	validation_0-rmse:0.002399	validation_1-rmse:0.138414
# [181]	validation_0-rmse:0.002353	validation_1-rmse:0.138424
# [182]	validation_0-rmse:0.002273	validation_1-rmse:0.138419
# [183]	validation_0-rmse:0.002222	validation_1-rmse:0.138425
# [184]	validation_0-rmse:0.002168	validation_1-rmse:0.13843
# [185]	validation_0-rmse:0.002115	validation_1-rmse:0.138433
# [186]	validation_0-rmse:0.002066	validation_1-rmse:0.138432
# [187]	validation_0-rmse:0.002019	validation_1-rmse:0.138434
# [188]	validation_0-rmse:0.001971	validation_1-rmse:0.13844
# [189]	validation_0-rmse:0.001923	validation_1-rmse:0.138435
# [190]	validation_0-rmse:0.001878	validation_1-rmse:0.138434
# [191]	validation_0-rmse:0.001842	validation_1-rmse:0.138433
# [192]	validation_0-rmse:0.001796	validation_1-rmse:0.138443
# [193]	validation_0-rmse:0.001743	validation_1-rmse:0.138449
# [194]	validation_0-rmse:0.001682	validation_1-rmse:0.13846
# [195]	validation_0-rmse:0.001659	validation_1-rmse:0.138468
# [196]	validation_0-rmse:0.001628	validation_1-rmse:0.138467
# [197]	validation_0-rmse:0.001597	validation_1-rmse:0.138463
# [198]	validation_0-rmse:0.001562	validation_1-rmse:0.138467
# [199]	validation_0-rmse:0.00151	validation_1-rmse:0.13847
# [200]	validation_0-rmse:0.001481	validation_1-rmse:0.138466
# [201]	validation_0-rmse:0.001444	validation_1-rmse:0.138468
# [202]	validation_0-rmse:0.001425	validation_1-rmse:0.138462
# [203]	validation_0-rmse:0.001386	validation_1-rmse:0.138462
# [204]	validation_0-rmse:0.001356	validation_1-rmse:0.138457
# [205]	validation_0-rmse:0.001327	validation_1-rmse:0.138457
# [206]	validation_0-rmse:0.001292	validation_1-rmse:0.138463
# [207]	validation_0-rmse:0.001259	validation_1-rmse:0.138459
# [208]	validation_0-rmse:0.001231	validation_1-rmse:0.138464
# [209]	validation_0-rmse:0.001219	validation_1-rmse:0.138465
# [210]	validation_0-rmse:0.001205	validation_1-rmse:0.138466
# [211]	validation_0-rmse:0.001184	validation_1-rmse:0.138476
# [212]	validation_0-rmse:0.001162	validation_1-rmse:0.138471
# [213]	validation_0-rmse:0.00114	validation_1-rmse:0.138473
# [214]	validation_0-rmse:0.001113	validation_1-rmse:0.138469
# [215]	validation_0-rmse:0.001081	validation_1-rmse:0.138467
# [216]	validation_0-rmse:0.001069	validation_1-rmse:0.138467
# [217]	validation_0-rmse:0.001046	validation_1-rmse:0.138464
# [218]	validation_0-rmse:0.001023	validation_1-rmse:0.138463
# [219]	validation_0-rmse:0.000995	validation_1-rmse:0.138463
# [220]	validation_0-rmse:0.000964	validation_1-rmse:0.138463
# [221]	validation_0-rmse:0.000946	validation_1-rmse:0.138463
# [222]	validation_0-rmse:0.000922	validation_1-rmse:0.138463
# [223]	validation_0-rmse:0.000908	validation_1-rmse:0.138465
# [224]	validation_0-rmse:0.000888	validation_1-rmse:0.138462
# [225]	validation_0-rmse:0.000866	validation_1-rmse:0.138459
# [226]	validation_0-rmse:0.000847	validation_1-rmse:0.138463
# [227]	validation_0-rmse:0.000832	validation_1-rmse:0.138463
# [228]	validation_0-rmse:0.000811	validation_1-rmse:0.138469
# [229]	validation_0-rmse:0.000786	validation_1-rmse:0.138471
# [230]	validation_0-rmse:0.000775	validation_1-rmse:0.138473
# [231]	validation_0-rmse:0.000762	validation_1-rmse:0.138474
# [232]	validation_0-rmse:0.000741	validation_1-rmse:0.13847
# [233]	validation_0-rmse:0.000728	validation_1-rmse:0.138472
# [234]	validation_0-rmse:0.00071	validation_1-rmse:0.138472
# [235]	validation_0-rmse:0.000703	validation_1-rmse:0.13847
# [236]	validation_0-rmse:0.000691	validation_1-rmse:0.138469
# [237]	validation_0-rmse:0.000677	validation_1-rmse:0.138471
# [238]	validation_0-rmse:0.000674	validation_1-rmse:0.138471
# [239]	validation_0-rmse:0.000658	validation_1-rmse:0.138471
# [240]	validation_0-rmse:0.000646	validation_1-rmse:0.138472
# [241]	validation_0-rmse:0.000638	validation_1-rmse:0.138471
# [242]	validation_0-rmse:0.000632	validation_1-rmse:0.13847
# [243]	validation_0-rmse:0.000626	validation_1-rmse:0.138472
# [244]	validation_0-rmse:0.000615	validation_1-rmse:0.13847
# [245]	validation_0-rmse:0.000604	validation_1-rmse:0.138471
# [246]	validation_0-rmse:0.000597	validation_1-rmse:0.13847
# [247]	validation_0-rmse:0.000587	validation_1-rmse:0.138469
# [248]	validation_0-rmse:0.000584	validation_1-rmse:0.13847
# [249]	validation_0-rmse:0.00058	validation_1-rmse:0.13847
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, eta=0.1, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=10, min_child_weight=1, missing=None, n_estimators=250,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=0.7, verbosity=1)

# %% [markdown]
# # Predictions

# %%
y_prd = xgb_reg.predict(df_x)

# %%
# transforming predicted values to the orginal scal log1p - expm1
df_x['predict_count'] = np.expm1(y_prd)
df_x['count'] = np.expm1(y)

# %%
#numarical_features

# %%
# test data processing and predictions

# transforming years
test_num = year_transform(test.drop('Id',axis=1))

# transforming the skewed numarical features
test_num = skew_transform(test_num)

# Catagorical feature transformations
test_cat = cata_transform(test,catagorical_features)

# Adding new features 
test_x = add_new_features(pd.concat([test_num,test_cat],axis=1))

# %%
# test predictions
y_test_pred = xgb_reg.predict(test_x)

# %%
#transforming predicted values expm1 - log1p
test['predict_count'] = np.expm1(y_test_pred)

# %%
final_submission = pd.DataFrame({
        "Id": test["Id"],
        "SalePrice": test['predict_count']
    })
final_submission.to_csv("final_submission.csv", index=False)
final_submission.head()
# Out:
#      Id      SalePrice
# 0  1461  117917.242188
# 1  1462  126143.937500
# 2  1463  152174.656250
# 3  1464  164989.984375
# 4  1465  192705.468750

# %%
# predicdicted values stats
test['predict_count'].describe()
# Out:
# count      1459.000000
# mean     148352.390625
# std       45799.621094
# min       59213.863281
# 25%      115811.035156
# 50%      133720.750000
# 75%      173193.250000
# max      295861.062500
# Name: predict_count, dtype: float64

# %% [markdown]
# # Train,Validation Error Plots

# %%
# evaluations
eval_result = xgb_reg.evals_result()
training_rounds = range(len(eval_result['validation_0']['rmse']))

# %%
# plot traing and testing error

plt.scatter(x=training_rounds,y=eval_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=eval_result['validation_1']['rmse'],label='Validation Error')
plt.grid(True)
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Training Vs Validation Error')
plt.legend()
plt.show()

# %%
# feature importance 

features_imp = pd.DataFrame({'feature':df_x.drop(['predict_count','count'],axis=1).columns,'importance':xgb_reg.feature_importances_})
#features_imp

# %%
features_imp.sort_values(by='importance',ascending=False)[:10]
# Out:
#             feature  importance
# 40       GarageCond    0.140711
# 28       GarageCars    0.137757
# 65       CentralAir    0.078411
# 13      OverallQual    0.072056
# 77      KitchenQual    0.070710
# 46         BsmtQual    0.057291
# 41     GarageFinish    0.053358
# 29        GrLivArea    0.047349
# 80  Total_Bathrooms    0.042529
# 53     Neighborhood    0.031250

# %%
# Metric Use By Kaggle
def compute_rmsle(y_true, y_pred):
    if type(y_true) != np.ndarray:
        y_true = np.array(y_true)
        
    if type(y_pred) != np.ndarray:
        y_pred = np.array(y_pred)
     
    return(np.average((np.log1p(y_pred) - np.log1p(y_true))**2)**.5)

# %%
df_x['predict_count'].describe()
# Out:
# count      1460.000000
# mean     180605.640625
# std       77726.671875
# min       34915.250000
# 25%      129357.220703
# 50%      163814.015625
# 75%      214032.460938
# max      744619.437500
# Name: predict_count, dtype: float64

# %%
compute_rmsle(df_x['predict_count'],df_x['count'])
# Out:
# 0.06192769201463892

# %% [markdown]
# #  Residual Error distribution

# %%
residuals  = np.expm1(y) - np.expm1(y_prd)

# %%
plt.hist(residuals)
plt.grid(True)
plt.xlabel('Actual - Predicted')
plt.xlim(-50000,80000)
plt.ylabel('Count')
plt.title('Residuals Distribution')
plt.axvline(color='r')
plt.show()

# %% [markdown]
# * our model overesting the target value

# %% [markdown]
# #  Save Model

# %%
from sklearn.externals import joblib

# %%
# save the model to disk
filename = 'finalized_xgb_reg.sav'
joblib.dump(xgb_reg, filename)

# %%
## including predictions

df_x.to_csv('train_pred.csv')
test_x.to_csv('test_pred.csv')
